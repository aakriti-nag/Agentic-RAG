# %% [markdown]
# ### 🧠 Answer Synthesis from Multiple Sources
# ✅ What Is It?
#
# Answer synthesis from multiple sources is the process where an AI agent collects information from different retrieval tools or knowledge bases, and merges that information into a single, coherent, and contextually rich answer.
#
# This is a core capability in Agentic RAG, where the system is more than just a simple retriever — it plans, retrieves, and then synthesizes an answer that draws from multiple sources.

# %% [markdown]
# 🎯 Why It’s Needed
# Most real-world queries are:
# - Multifaceted (require multiple types of information)
# - Ambiguous or incomplete (need refinement)
# - Open-ended (don’t map to a single document or source)
#
# 🔍 This makes retrieving from a single vector DB insufficient.
#
# Instead, we want an agent that can:
#
# - Decide what to fetch from where (retrieval planning)
# - Retrieve content from multiple tools (e.g., Wikipedia, PDFs, APIs, SQL)
# - Evaluate and merge that context
# - Produce a single human-like response

# %%
import os
from typing import List
from pydantic import BaseModel
from langchain.chat_models import init_chat_model
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document
from langchain_community.vectorstores import FAISS
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders.youtube import YoutubeLoader
from langchain_community.document_loaders import ArxivLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper
from langgraph.graph import StateGraph, END

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
llm=init_chat_model("openai:gpt-4o-mini")

# %%
from langchain_core.tools import tool

def load_text_retriever(file_path):
    docs = TextLoader(file_path, encoding="utf-8").load()
    splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    chunks = splitter.split_documents(docs)
    vs = FAISS.from_documents(chunks, OpenAIEmbeddings())
    return vs.as_retriever()


def load_youtube_retriever():
    # Mocked YouTube transcript text
    content = """
    This video explains how agentic AI systems rely on feedback loops, memory, and tool use.
    It compares them to traditional pipeline-based LLMs. Temporal reasoning and autonomous tasking are emphasized.
    """
    doc = Document(page_content=content, metadata={"source": "youtube"})
    vectorstore = FAISS.from_documents([doc], OpenAIEmbeddings())
    return vectorstore.as_retriever()


wiki_tool = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper())
@tool("Wikipedia")

def wikipedia_search(query: str) -> str:
    """Fetch general world knowledge from Wikipedia."""
    print("🌐 Searching Wikipedia...")
    return wiki_tool.invoke({"query": query})

def arxiv_search(query: str) -> str:
    print("📄 Searching ArXiv...")
    results = ArxivLoader(query).load()
    return "\n\n".join(doc.page_content for doc in results[:2]) or "No relevant papers found."

# %%
text_retriever = load_text_retriever("autonomous_rag_explained.txt")
youtube_retriever = load_youtube_retriever()

# %%
### state
class MultiSourceRAGState(BaseModel):
    question: str
    text_docs: List[Document] = []
    yt_docs: List[Document] = []
    wiki_context: str = ""
    arxiv_context: str = ""
    final_answer: str = ""

# %%
### Retrieval Nodes
def retrieve_text(state: MultiSourceRAGState) -> MultiSourceRAGState:
    docs = text_retriever.invoke(state.question)
    return state.model_copy(update={"text_docs": docs})

def retrieve_yt(state: MultiSourceRAGState) -> MultiSourceRAGState:
    docs = youtube_retriever.invoke(state.question)
    return state.model_copy(update={"yt_docs": docs})

def retrieve_wikipedia(state: MultiSourceRAGState) -> MultiSourceRAGState:
    result = wikipedia_search.invoke({"query": state.question})
    return state.model_copy(update={"wiki_context": result})

def retrieve_arxiv(state: MultiSourceRAGState) -> MultiSourceRAGState:
    result = arxiv_search(state.question)
    return state.model_copy(update={"arxiv_context": result})

# %%
## synthesize
def synthesize_answer(state: MultiSourceRAGState) -> MultiSourceRAGState:
    
    context = ""

    context += "\n\n[Internal Docs]\n" + "\n".join([doc.page_content for doc in state.text_docs])
    context += "\n\n[YouTube Transcript]\n" + "\n".join([doc.page_content for doc in state.yt_docs])
    context += "\n\n[Wikipedia]\n" + state.wiki_context
    context += "\n\n[ArXiv]\n" + state.arxiv_context

    prompt = f"""You have retrieved relevant context from multiple sources. Now synthesize a complete and coherent answer.

Question: {state.question}

Context:
{context}

Final Answer:"""

    answer = llm.invoke(prompt).content.strip()
    return state.model_copy(update={"final_answer": answer})

# %%
builder = StateGraph(MultiSourceRAGState)

builder.add_node("retrieve_text", retrieve_text)
builder.add_node("retrieve_yt", retrieve_yt)
builder.add_node("retrieve_wiki", retrieve_wikipedia)
builder.add_node("retrieve_arxiv", retrieve_arxiv)
builder.add_node("synthesize", synthesize_answer)

builder.set_entry_point("retrieve_text")
builder.add_edge("retrieve_text", "retrieve_yt")
builder.add_edge("retrieve_yt", "retrieve_wiki")
builder.add_edge("retrieve_wiki", "retrieve_arxiv")
builder.add_edge("retrieve_arxiv", "synthesize")
builder.add_edge("synthesize", END)

graph = builder.compile()
graph

# %%
question = "What are transformer agents and how are they evolving in recent research?"
state = MultiSourceRAGState(question=question)
result = graph.invoke(state)

print("✅ Final Answer:\n")
print(result["final_answer"])
# Out:
# 🌐 Searching Wikipedia...
# 📄 Searching ArXiv...
# ✅ Final Answer:
#
# **Transformer Agents: An Overview and Recent Research Developments**
#
# Transformer agents are advanced forms of artificial intelligence systems that utilize transformer architecture, particularly large language models (LLMs), to perform complex tasks in various environments. These agents leverage capabilities such as decision-making, communication, and adaptability to interact with their surroundings more effectively than traditional AI models.
#
# ### Conceptual Foundation of Transformer Agents
# 1. **Memory and State**: Transformer agents operate with an internal state that captures critical information, including user interactions, previous actions, and contextual data. This functions like the "memory" of the agent, allowing it to reference past experiences when making decisions.
#
# 2. **Autonomous Decision-Making**: Central to transformer agents is their ability to autonomously decide when to retrieve external information or when to act based on current knowledge. This self-contained decision-making is facilitated by components known as autonomous Retrieval-Augmented Generation (RAG) frameworks, which help the agent refine its questions and improve confidence in its responses before taking action.
#
# 3. **Tool and Resource Usage**: These agents often utilize various tools, including databases, web searches, and model optimization techniques, to enrich their capacity for reasoning and response generation. For instance, they may dynamically choose which tool to apply based on the context of the task at hand.
#
# ### Evolving Research Directions
# Recent research has focused on enhancing the capabilities of transformer agents through self-evolving techniques, smoothly bridging static capabilities with ongoing adaptability. Below are emerging trends and advancements in transformer agent research:
#
# 1. **Self-Evolving Architectures**: New frameworks have been proposed that allow transformer agents to continuously learn and adapt based on interactions with their environment. This includes mechanisms for refining their internal parameters, optimizing communication strategies, and enhancing the efficiency of their operational workflows.
#
# 2. **Multi-Agent Systems**: Researchers are exploring the benefits of multi-agent architectures, where multiple transformer agents collaborate to tackle larger and more complex tasks. Such systems can leverage individual agents' strengths, leading to greater overall effectiveness in problem-solving and decision-making by enabling specialization and efficient communication among agents.
#
# 3. **Communication Protocols**: As communication is vital for multi-agent systems, current studies are investigating how agents can develop their communication protocols dynamically. This includes experimenting with various message types, communication frequency, and the implications of communication costs on overall performance.
#
# 4. **Integrating External Knowledge**: Self-evolving agents are increasingly expected to integrate external knowledge dynamically, adjusting to new information sources and environments. This includes accessing real-time data and deploying different reasoning strategies based on the agents’ current tasks.
#
# 5. **Evaluation and Safety Measures**: There’s a growing emphasis on evaluating the performance and safety of transformer agents, particularly in terms of how they adapt to complex environments and potential adversarial scenarios. This involves developing benchmarks and metrics that assess not only the effectiveness of the agents but also their robustness and compliance with safety standards.
#
# ### Conclusion
# The field of transformer agents is rapidly evolving, characterized by significant leaps in autonomy and adaptability. With ongoing advancements in self-evolving systems, multi-agent collaboration, and dynamic communication, researchers are laying the foundation for sophisticated AI systems capable of operating in real-world, complex environments. As this research progresses, special attention will need to be paid to safety and evaluation methodologies to ensure that these powerful tools can be deployed responsibly.
